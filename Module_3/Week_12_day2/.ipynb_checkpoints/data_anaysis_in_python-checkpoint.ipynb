# %%
import pandas as pd
import numpy as np

# %%
instructors_dataframe = pd.DataFrame({
    "name" : ["Del", "Aileen", "Mhairi", "Mandy"], 
    "favourite number" : [7,3,12,9]},
    index = [22,25,40,35])

instructors_dataframe
# Out:
#       name  favourite number
# 22     Del                 7
# 25  Aileen                 3
# 40  Mhairi                12
# 35   Mandy                 9

# %%
life_expectancy = pd.read_csv("life_expectancy_and_income.csv")

# %%
life_expectancy
# Out:
#            country  year  fertility_rate  income_per_person  life_expectancy
# 0      Afghanistan  1900            7.00               1090             29.4
# 1      Afghanistan  1901            7.00               1110             29.5
# 2      Afghanistan  1902            7.00               1120             29.5
# 3      Afghanistan  1903            7.00               1140             29.6
# 4      Afghanistan  1904            7.00               1160             29.7
# ...            ...   ...             ...                ...              ...
# 22075     Zimbabwe  2015            3.84               2510             59.6
# 22076     Zimbabwe  2016            3.76               2490             60.5
# 22077     Zimbabwe  2017            3.68               2570             61.4
# 22078     Zimbabwe  2018            3.61               2620             61.7
# 22079     Zimbabwe  2019            3.53               2390             62.0
#
# [22080 rows x 5 columns]

# %%
type(life_expectancy)
# Out:
# pandas.core.frame.DataFrame

# %%
life_expectancy.head(2)
# Out:
#        country  year  fertility_rate  income_per_person  life_expectancy
# 0  Afghanistan  1900             7.0               1090             29.4
# 1  Afghanistan  1901             7.0               1110             29.5

# %%
life_expectancy.tail()
# Out:
#         country  year  fertility_rate  income_per_person  life_expectancy
# 22075  Zimbabwe  2015            3.84               2510             59.6
# 22076  Zimbabwe  2016            3.76               2490             60.5
# 22077  Zimbabwe  2017            3.68               2570             61.4
# 22078  Zimbabwe  2018            3.61               2620             61.7
# 22079  Zimbabwe  2019            3.53               2390             62.0

# %%
life_expectancy.shape
# Out:
# (22080, 5)

# %%
life_expectancy.columns
# Out:
# Index(['country', 'year', 'fertility_rate', 'income_per_person',
#        'life_expectancy'],
#       dtype='object')

# %%
life_expectancy.describe()
# Out:
#                year  fertility_rate  income_per_person  life_expectancy
# count  22080.000000    22080.000000       22080.000000     22080.000000
# mean    1959.500000        4.840770        7607.700996        52.567773
# std       34.640598        1.916428       13448.408600        16.773059
# min     1900.000000        1.120000         312.000000         1.100000
# 25%     1929.750000        2.980000        1370.000000        35.700000
# 50%     1959.500000        5.450000        2880.000000        53.550000
# 75%     1989.250000        6.500000        7702.500000        68.200000
# max     2019.000000        8.870000      179000.000000        85.100000

# %%
pd.DataFrame?

# %%
prestige = pd.read_csv("prestige_occupation.csv")
prestige
# Out:
#                      job  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753    NaN      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
prestige.describe()
# Out:
#         education        income      women    prestige       census
# count  102.000000    102.000000  97.000000  102.000000   102.000000
# mean    10.738039   6797.901961  30.472784   46.833333  5401.774510
# std      2.728444   4245.922227  31.826063   17.204486  2644.993215
# min      6.380000    611.000000   0.520000   14.800000  1113.000000
# 25%      8.445000   4106.000000   4.140000   35.225000  3120.500000
# 50%     10.540000   5930.500000  15.510000   43.600000  5135.000000
# 75%     12.647500   8187.250000  54.770000   59.275000  8312.500000
# max     15.970000  25879.000000  97.510000   87.200000  9517.000000

# %%
prestige["prestige"].mean()
# Out:
# 46.833333333333314

# %%
life_expectancy["year"]
# Out:
# 0        1900
# 1        1901
# 2        1902
# 3        1903
# 4        1904
#          ...
# 22075    2015
# 22076    2016
# 22077    2017
# 22078    2018
# 22079    2019
# Name: year, Length: 22080, dtype: int64

# %%
life_expectancy_subset = life_expectancy[["year", "country"]]

# %%
life_expectancy_subset
# Out:
#        year      country
# 0      1900  Afghanistan
# 1      1901  Afghanistan
# 2      1902  Afghanistan
# 3      1903  Afghanistan
# 4      1904  Afghanistan
# ...     ...          ...
# 22075  2015     Zimbabwe
# 22076  2016     Zimbabwe
# 22077  2017     Zimbabwe
# 22078  2018     Zimbabwe
# 22079  2019     Zimbabwe
#
# [22080 rows x 2 columns]

# %%
np.mean(life_expectancy["life_expectancy"])
# Out:
# 52.56777309782635

# %%
job_incomes = prestige[["job", "type", "income"]]

# %%
job_incomes
# Out:
#                      job  type  income
# 0     gov.administrators  prof   12351
# 1       general.managers  prof   25879
# 2            accountants  prof    9271
# 3    purchasing.officers  prof    8865
# 4               chemists  prof    8403
# ..                   ...   ...     ...
# 97           bus.drivers    bc    5562
# 98          taxi.drivers    bc    4224
# 99          longshoremen    bc    4753
# 100          typesetters    bc    6462
# 101          bookbinders    bc    3617
#
# [102 rows x 3 columns]

# %%
np.mean(prestige["prestige"])
# Out:
# 46.833333333333314

# %%
np.median(prestige["prestige"])
# Out:
# 43.6

# %%
life_expectancy.loc[life_expectancy["country"] == "Japan"]
# Out:
#      country  year  fertility_rate  income_per_person  life_expectancy
# 9720   Japan  1900            4.69               1860             38.7
# 9721   Japan  1901            5.01               1900             38.8
# 9722   Japan  1902            4.97               1780             39.0
# 9723   Japan  1903            4.83               1880             39.1
# 9724   Japan  1904            4.61               1870             39.2
# ...      ...   ...             ...                ...              ...
# 9835   Japan  2015            1.44              37800             84.1
# 9836   Japan  2016            1.46              38100             84.2
# 9837   Japan  2017            1.47              38900             84.2
# 9838   Japan  2018            1.48              39300             84.4
# 9839   Japan  2019            1.50              39700             84.5
#
# [120 rows x 5 columns]

# %%
life_expectancy.loc[life_expectancy["life_expectancy"].idxmin()]
# Out:
# country              Samoa
# year                  1918
# fertility_rate        6.98
# income_per_person     2050
# life_expectancy        1.1
# Name: 16338, dtype: object

# %%
prestige.loc[[prestige["income"].idxmin(), prestige["income"].idxmax()]]
# Out:
#                  job  education  income  women  prestige  census  type
# 62       babysitters       9.46     611  96.53      25.9    6147   NaN
# 1   general.managers      12.26   25879   4.02      69.1    1130  prof

# %%
blue_collar = prestige.loc[prestige["type"] == "bc"]
blue_collar
# Out:
#                            job  education  income  women  prestige  census  \
# 27               nursing.aides       9.45    3485  76.14      34.9    3135
# 53   service.station.attendant       9.93    2370   3.69      23.3    5145
# 57                firefighters       9.47    8895    NaN      43.5    6111
# 58                   policemen      10.93    8891   1.65      51.6    6112
# 59                       cooks       7.74    3116  52.00      29.7    6121
# 60                  bartenders       8.50    3930  15.51      20.2    6123
# 61           funeral.directors      10.57    7869   6.01      54.9    6141
# 63                  launderers       7.33    3000  69.31      20.8    6162
# 64                    janitors       7.11    3472  33.57      17.3    6191
# 65          elevator.operators       7.58    3582  30.08      20.1    6193
# 67                farm.workers       8.60    1656  27.75      21.5    7182
# ...

# %%
prestige["type"].unique()
# Out:
# array(['prof', 'bc', 'wc', nan], dtype=object)

# %%
life_expectancy.sort_values("life_expectancy", ascending= False) # argument inplace = True will also 
                                                                #affect the main dataframe
# Out:
#           country  year  fertility_rate  income_per_person  life_expectancy
# 17279   Singapore  2019            1.27              90100            85.10
# 17278   Singapore  2018            1.26              90100            85.00
# 17277   Singapore  2017            1.25              87800            84.80
# 17276   Singapore  2016            1.25              84700            84.70
# 9839        Japan  2019            1.50              39700            84.50
# ...           ...   ...             ...                ...              ...
# 19938       Tonga  1918            6.51                969             5.96
# 3378     Cameroon  1918            5.54               1030             5.95
# 13444     Namibia  1904            5.96               1900             5.19
# 9993   Kazakhstan  1933            5.85               3120             4.07
# 16338       Samoa  1918            6.98               2050             1.10
#
# [22080 rows x 5 columns]

# %%
life_expectancy.rename(columns = {"income_per_person" : "income_gdp_per_head"}, inplace = True)
life_expectancy
# Out:
#            country  year  fertility_rate  income_gdp_per_head  life_expectancy
# 0      Afghanistan  1900            7.00                 1090             29.4
# 1      Afghanistan  1901            7.00                 1110             29.5
# 2      Afghanistan  1902            7.00                 1120             29.5
# 3      Afghanistan  1903            7.00                 1140             29.6
# 4      Afghanistan  1904            7.00                 1160             29.7
# ...            ...   ...             ...                  ...              ...
# 22075     Zimbabwe  2015            3.84                 2510             59.6
# 22076     Zimbabwe  2016            3.76                 2490             60.5
# 22077     Zimbabwe  2017            3.68                 2570             61.4
# 22078     Zimbabwe  2018            3.61                 2620             61.7
# 22079     Zimbabwe  2019            3.53                 2390             62.0
#
# ...

# %%
prestige.rename(columns= {"job" : "job_title"}, inplace= True)

# %%
prestige
# Out:
#                job_title  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753    NaN      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
life_expectancy["year_since_1990"] = life_expectancy["year"] - 1990
life_expectancy
# Out:
#            country  year  fertility_rate  income_gdp_per_head  \
# 0      Afghanistan  1900            7.00                 1090
# 1      Afghanistan  1901            7.00                 1110
# 2      Afghanistan  1902            7.00                 1120
# 3      Afghanistan  1903            7.00                 1140
# 4      Afghanistan  1904            7.00                 1160
# ...            ...   ...             ...                  ...
# 22075     Zimbabwe  2015            3.84                 2510
# 22076     Zimbabwe  2016            3.76                 2490
# 22077     Zimbabwe  2017            3.68                 2570
# 22078     Zimbabwe  2018            3.61                 2620
# 22079     Zimbabwe  2019            3.53                 2390
#
#        life_expectancy  year_since_1990
# 0                 29.4              -90
# 1                 29.5              -89
# 2                 29.5              -88
# 3                 29.6              -87
# ...

# %%
life_expectancy["income_gdp_per_head"] = life_expectancy["income_gdp_per_head"] * 0.8
life_expectancy
# Out:
#            country  year  fertility_rate  income_gdp_per_head  \
# 0      Afghanistan  1900            7.00               558.08
# 1      Afghanistan  1901            7.00               568.32
# 2      Afghanistan  1902            7.00               573.44
# 3      Afghanistan  1903            7.00               583.68
# 4      Afghanistan  1904            7.00               593.92
# ...            ...   ...             ...                  ...
# 22075     Zimbabwe  2015            3.84              1285.12
# 22076     Zimbabwe  2016            3.76              1274.88
# 22077     Zimbabwe  2017            3.68              1315.84
# 22078     Zimbabwe  2018            3.61              1341.44
# 22079     Zimbabwe  2019            3.53              1223.68
#
#        life_expectancy  year_since_1990
# 0                 29.4              -90
# 1                 29.5              -89
# 2                 29.5              -88
# 3                 29.6              -87
# ...

# %%
.map(function) #applies function to the full column
# Out:
#   File "<ipython-input-63-bb4b5be8dbe8>", line 1
#     .map(function) #applies function to the full column
#     ^
# SyntaxError: invalid syntax

# %%
prestige.head()
# Out:
#              job_title  education  income  women  prestige  census  type
# 0   gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1     general.managers      12.26   25879   4.02      69.1    1130  prof
# 2          accountants      12.77    9271  15.70      63.4    1171  prof
# 3  purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4             chemists      14.62    8403  11.68      73.5    2111  prof

# %%
prestige["income_in_1000s_USD"] = (prestige["income"]/1000).map(round)

# %%
prestige
# Out:
#                job_title  education  income  women  prestige  census  type  \
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753    NaN      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
#      income_in_1000s_USD
# 0                     12
# ...

# %%
life_expectancy.groupby("country").mean()
# Out:
#                        year  fertility_rate  income_gdp_per_head  \
# country
# Afghanistan          1959.5        7.081250           936.046933
# Albania              1959.5        4.023000          1857.962667
# Algeria              1959.5        6.085500          3492.736000
# Angola               1959.5        7.009833          1772.343467
# Antigua and Barbuda  1959.5        3.568250          4297.642667
# ...                     ...             ...                  ...
# Venezuela            1959.5        4.817583          5303.978667
# Vietnam              1959.5        4.376167           879.718400
# Yemen                1959.5        7.021583          1143.594667
# Zambia               1959.5        6.569250          1081.365333
# Zimbabwe             1959.5        6.167833           880.166400
#
#                      life_expectancy  year_since_1990
# country
# Afghanistan                41.135583            -30.5
# Albania                    56.780833            -30.5
# ...

# %%
life_expectancy.groupby("country")["income_gdp_per_head"].mean()
# Out:
# country
# Afghanistan             936.046933
# Albania                1857.962667
# Algeria                3492.736000
# Angola                 1772.343467
# Antigua and Barbuda    4297.642667
#                           ...
# Venezuela              5303.978667
# Vietnam                 879.718400
# Yemen                  1143.594667
# Zambia                 1081.365333
# Zimbabwe                880.166400
# Name: income_gdp_per_head, Length: 184, dtype: float64

# %%
life_expectancy.groupby("year").describe()
# Out:
#      fertility_rate                                                         \
#               count      mean       std   min     25%    50%     75%   max
# year
# 1900          184.0  5.905978  1.022217  2.80  5.3475  6.105  6.6750  8.05
# 1901          184.0  5.904348  1.010395  2.90  5.3575  6.105  6.6450  8.04
# 1902          184.0  5.897772  1.018702  2.85  5.3525  6.120  6.6450  8.03
# 1903          184.0  5.883859  1.032254  2.78  5.2700  6.120  6.6450  8.02
# 1904          184.0  5.868533  1.038435  2.75  5.2300  6.110  6.6450  8.01
# ...             ...       ...       ...   ...     ...    ...     ...   ...
# 2015          184.0  2.835924  1.372184  1.24  1.7775  2.335  3.8425  7.29
# 2016          184.0  2.801957  1.343670  1.24  1.7500  2.315  3.7675  7.24
# 2017          184.0  2.769348  1.314814  1.23  1.7575  2.285  3.6900  7.18
# 2018          184.0  2.737609  1.286030  1.23  1.7500  2.265  3.6225  7.13
# ...

# %%
prestige.head()
# Out:
#              job_title  education  income  women  prestige  census  type  \
# 0   gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1     general.managers      12.26   25879   4.02      69.1    1130  prof
# 2          accountants      12.77    9271  15.70      63.4    1171  prof
# 3  purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4             chemists      14.62    8403  11.68      73.5    2111  prof
#
#    income_in_1000s_USD
# 0                   12
# 1                   26
# 2                    9
# 3                    9
# 4                    8

# %%
prestige.groupby("type")["income_in_1000s_USD"].max()
# Out:
# type
# bc       9
# prof    26
# wc       9
# Name: income_in_1000s_USD, dtype: int64

# %%
prestige.groupby("type")["prestige"].mean()
# Out:
# type
# bc      35.527273
# prof    67.848387
# wc      42.243478
# Name: prestige, dtype: float64

# %%
prestige.groupby("type")["women"].idxmin()
# Out:
# type
# bc      91
# prof    95
# wc      50
# Name: women, dtype: int64

# %%
life_expectancy.isna().sum()
# Out:
# country                0
# year                   0
# fertility_rate         0
# income_gdp_per_head    0
# life_expectancy        0
# year_since_1990        0
# dtype: int64

# %%
life_expectancy.fillna(0)
# Out:
#            country  year  fertility_rate  income_gdp_per_head  \
# 0      Afghanistan  1900            7.00               558.08
# 1      Afghanistan  1901            7.00               568.32
# 2      Afghanistan  1902            7.00               573.44
# 3      Afghanistan  1903            7.00               583.68
# 4      Afghanistan  1904            7.00               593.92
# ...            ...   ...             ...                  ...
# 22075     Zimbabwe  2015            3.84              1285.12
# 22076     Zimbabwe  2016            3.76              1274.88
# 22077     Zimbabwe  2017            3.68              1315.84
# 22078     Zimbabwe  2018            3.61              1341.44
# 22079     Zimbabwe  2019            3.53              1223.68
#
#        life_expectancy  year_since_1990
# 0                 29.4              -90
# 1                 29.5              -89
# 2                 29.5              -88
# 3                 29.6              -87
# ...

# %%
life_expectancy.fillna({
    "life_expectancy" : np.mean(life_expectancy["life_expectancy"]),
    "income_gdp_per_head" : np.mean(life_expectancy["income_gdp_per_head"])
})
# Out:
#            country  year  fertility_rate  income_gdp_per_head  \
# 0      Afghanistan  1900            7.00               558.08
# 1      Afghanistan  1901            7.00               568.32
# 2      Afghanistan  1902            7.00               573.44
# 3      Afghanistan  1903            7.00               583.68
# 4      Afghanistan  1904            7.00               593.92
# ...            ...   ...             ...                  ...
# 22075     Zimbabwe  2015            3.84              1285.12
# 22076     Zimbabwe  2016            3.76              1274.88
# 22077     Zimbabwe  2017            3.68              1315.84
# 22078     Zimbabwe  2018            3.61              1341.44
# 22079     Zimbabwe  2019            3.53              1223.68
#
#        life_expectancy  year_since_1990
# 0                 29.4              -90
# 1                 29.5              -89
# 2                 29.5              -88
# 3                 29.6              -87
# ...

# %%
life_expectancy.dropna()
# Out:
#            country  year  fertility_rate  income_gdp_per_head  \
# 0      Afghanistan  1900            7.00               558.08
# 1      Afghanistan  1901            7.00               568.32
# 2      Afghanistan  1902            7.00               573.44
# 3      Afghanistan  1903            7.00               583.68
# 4      Afghanistan  1904            7.00               593.92
# ...            ...   ...             ...                  ...
# 22075     Zimbabwe  2015            3.84              1285.12
# 22076     Zimbabwe  2016            3.76              1274.88
# 22077     Zimbabwe  2017            3.68              1315.84
# 22078     Zimbabwe  2018            3.61              1341.44
# 22079     Zimbabwe  2019            3.53              1223.68
#
#        life_expectancy  year_since_1990
# 0                 29.4              -90
# 1                 29.5              -89
# 2                 29.5              -88
# 3                 29.6              -87
# ...

# %%
prestige.isna().sum()
# Out:
# job_title              0
# education              0
# income                 0
# women                  5
# prestige               0
# census                 0
# type                   4
# income_in_1000s_USD    0
# dtype: int64

# %%
prestige.fillna({"type" : "other"}, inplace=True)

# %%
prestige.isna().sum()
# Out:
# job_title              0
# education              0
# income                 0
# women                  5
# prestige               0
# census                 0
# type                   0
# income_in_1000s_USD    0
# dtype: int64

# %%
np.mean(prestige["women"])
# Out:
# 30.47278350515466

# %%
prestige.fillna({"women" : 0})["women"].mean()
# Out:
# 28.979019607843156

# %%
np.mean(prestige.dropna()["women"])
# Out:
# 30.47278350515466

# %%
# %matplotlib inline

# %%
life_expectancy["income_gdp_per_head"].plot(kind = "hist")

# %%
life_expectancy["income_gdp_per_head"].plot(kind = "box")

# %%
life_expectancy["income_gdp_per_head"].plot()

# %%
life_expectancy.plot(kind = "scatter", x = "income_gdp_per_head", y = "life_expectancy")

# %%
prestige = pd.read_csv("prestige_occupation.csv")
prestige
# Out:
#                      job  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753    NaN      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
prestige["income"].plot(kind = "hist")

# %%
prestige["education"].plot(kind = "box")

# %%
scatter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-a44159f130bf> in <module>
# ----> 1 scatter()
#
# NameError: name 'scatter' is not defined

# %%
prestige.plot(kind = "scatter", x = "education", y = "prestige", c = "income", sharex = False)

# %%
life_expectancy
# Out:
#            country  year  fertility_rate  income_gdp_per_head  \
# 0      Afghanistan  1900            7.00               558.08
# 1      Afghanistan  1901            7.00               568.32
# 2      Afghanistan  1902            7.00               573.44
# 3      Afghanistan  1903            7.00               583.68
# 4      Afghanistan  1904            7.00               593.92
# ...            ...   ...             ...                  ...
# 22075     Zimbabwe  2015            3.84              1285.12
# 22076     Zimbabwe  2016            3.76              1274.88
# 22077     Zimbabwe  2017            3.68              1315.84
# 22078     Zimbabwe  2018            3.61              1341.44
# 22079     Zimbabwe  2019            3.53              1223.68
#
#        life_expectancy  year_since_1990
# 0                 29.4              -90
# 1                 29.5              -89
# 2                 29.5              -88
# 3                 29.6              -87
# ...

# %%
last_20 = life_expectancy.loc[life_expectancy["year"] > 2000]
by_year = last_20.groupby("year")["income_gdp_per_head"].mean()
by_year
# Out:
# year
# 2001    7122.507130
# 2002    7221.837913
# 2003    7386.359652
# 2004    7684.813913
# 2005    7886.046609
# 2006    8193.046261
# 2007    8460.104348
# 2008    8518.619826
# 2009    8179.517217
# 2010    8335.796870
# 2011    8459.430957
# 2012    8556.354783
# 2013    8622.466783
# 2014    8715.828870
# 2015    8844.207304
# 2016    8943.393391
# 2017    9087.195826
# 2018    9232.509217
# 2019    9318.068870
# Name: income_gdp_per_head, dtype: float64

# %%
by_year.plot(kind = "barh")

# %%
prestige
# Out:
#                      job  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753    NaN      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
prestige_per_job = prestige.groupby("type")["prestige"].mean()
prestige_per_job
# Out:
# type
# bc      35.527273
# prof    67.848387
# wc      42.243478
# Name: prestige, dtype: float64

# %%
prestige_per_job.plot(kind = "bar")

# %%
import seaborn as sns

# %%
sns.distplot(life_expectancy["income_gdp_per_head"], kde = False)

# %%
sns.boxplot(life_expectancy["income_gdp_per_head"])

# %%
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy", data = life_expectancy)

# %%
sns.barplot(x = "income_gdp_per_head", y = "year", data = last_20, estimator= np.mean, orient = "h", ci = None)

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(life_expectancy["income_gdp_per_head"])
plt.xlim(0, 30000)
# Out:
# (0, 30000)

# %%
sns.scatterplot(x = "education", y = "prestige", data = prestige)
plt.xlim(12, 16)
plt.ylim(50, 90)
# Out:
# (50, 90)

# %%
sns.distplot(life_expectancy["income_gdp_per_head"])
plt.xlabel("Income per head (£)")
plt.ylabel("Count")
plt.title("Plot of income_gdp_per_head")
# Out:
# Text(0.5, 1.0, 'Plot of income_gdp_per_head')

# %%
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy" ,data = life_expectancy)
plt.annotate("this is the highest life expectancy", xy = (70000, 85))
# Out:
# Text(70000, 85, 'this is the highest life expectancy')

# %%
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy", data = life_expectancy)
plt.xscale("log")

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy", data = life_expectancy)

# %%
sns.set_style("darkgrid")
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy", data = life_expectancy)

# %%
sns.set_style("dark")
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy", data = life_expectancy)

# %%
sns.set_style("ticks")
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy", data = life_expectancy)

# %%
sns.set_style("white") #default
sns.scatterplot(x = "income_gdp_per_head", y = "life_expectancy", data = life_expectancy)
